# %% [markdown]
# # Installing TPOT

# %%
# !pip install tpot
# Out:
# Requirement already satisfied: tpot in /opt/anaconda3/lib/python3.8/site-packages (0.11.7)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (4.62.0)
# Requirement already satisfied: joblib>=0.13.2 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.0.1)
# Requirement already satisfied: scipy>=1.3.1 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.7.1)
# Requirement already satisfied: xgboost>=1.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.4.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (0.24.2)
# Requirement already satisfied: update-checker>=0.16 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (0.18.0)
# Requirement already satisfied: pandas>=0.24.2 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.3.1)
# Requirement already satisfied: stopit>=1.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.1.2)
# Requirement already satisfied: numpy>=1.16.3 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.19.2)
# Requirement already satisfied: deap>=1.2 in /opt/anaconda3/lib/python3.8/site-packages (from tpot) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.2->tpot) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.2->tpot) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22.0->tpot) (2.2.0)
# Requirement already satisfied: requests>=2.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from update-checker>=0.16->tpot) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.26.6)

# %% [markdown]
# # Importing libraries and dependencies

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from tpot import TPOTRegressor

# %% [markdown]
# # Dataset Loading

# %%
data = pd.read_csv("../data/auto_insurance.csv")

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
data.dtypes
# Out:
# 0      int64
# 1    float64
# dtype: object

# %%
# split into input and output elements
data = data.values
data = data.astype('float32')

# %%
X = data[:, :-1]

# %%
y = data[:, :-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# # Evaluation Procedure

# %%
# define evaluation procedure
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# # Initializing Regressor

# %%
model = TPOTRegressor(generations=5, population_size=50, scoring='neg_mean_absolute_error', cv=cv, verbosity=2, random_state=1, n_jobs=-1)
# perform the search

# %% [markdown]
# # Search for the best model

# %%
# Feed the structured data regressor with training data.
model.fit(
    X_train, 
    y_train
)

print(model.score(X_test, y_test))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Optimization Progress:   0%|          | 0/300 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: -2.7544759101753395e-08
#
# Generation 2 - Current best internal CV score: -6.922225755564189e-13
#
# Generation 3 - Current best internal CV score: -6.922225755564189e-13
#
# Generation 4 - Current best internal CV score: -6.922225755564189e-13
#
# Generation 5 - Current best internal CV score: -4.1892415462522575e-15
#
# Best pipeline: LassoLarsCV(VarianceThreshold(SGDRegressor(input_matrix, alpha=0.0, eta0=1.0, fit_intercept=False, l1_ratio=0.5, learning_rate=constant, loss=epsilon_insensitive, penalty=elasticnet, power_t=1.0), threshold=0.0005), normalize=True)
# -6.695498856200944e-15
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %% [markdown]
# # Exporting Model

# %%
model.export('tpot_auto_insurance_pipeline.py')

# %%
# !cat tpot_auto_insurance_pipeline.py
# Out:
# import numpy as np
# import pandas as pd
# from sklearn.feature_selection import VarianceThreshold
# from sklearn.linear_model import LassoLarsCV, SGDRegressor
# from sklearn.model_selection import train_test_split
# from sklearn.pipeline import make_pipeline, make_union
# from tpot.builtins import StackingEstimator
# from tpot.export_utils import set_param_recursive
#
# # NOTE: Make sure that the outcome column is labeled 'target' in the data file
# tpot_data = pd.read_csv('PATH/TO/DATA/FILE', sep='COLUMN_SEPARATOR', dtype=np.float64)
# features = tpot_data.drop('target', axis=1)
# training_features, testing_features, training_target, testing_target = \
#             train_test_split(features, tpot_data['target'], random_state=1)
#
# # Average CV score on the training set was: -4.1892415462522575e-15
# exported_pipeline = make_pipeline(
#     StackingEstimator(estimator=SGDRegressor(alpha=0.0, eta0=1.0, fit_intercept=False, l1_ratio=0.5, learning_rate="constant", loss="epsilon_insensitive", penalty="elasticnet", power_t=1.0)),
#     VarianceThreshold(threshold=0.0005),
#     LassoLarsCV(normalize=True)
# )
# # Fix random state for all the steps in exported pipeline
# set_param_recursive(exported_pipeline.steps, 'random_state', 1)
#
# exported_pipeline.fit(training_features, training_target)
# results = exported_pipeline.predict(testing_features)

# %%
model.evaluated_individuals_

#Get details on algorithm TPOT searched for and how the performed on the dataset
# Out:
# {'XGBRegressor(RBFSampler(input_matrix, RBFSampler__gamma=0.4), XGBRegressor__learning_rate=0.01, XGBRegressor__max_depth=6, XGBRegressor__min_child_weight=16, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.05, XGBRegressor__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -19.4199999332428},
#  'XGBRegressor(input_matrix, XGBRegressor__learning_rate=0.01, XGBRegressor__max_depth=5, XGBRegressor__min_child_weight=17, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.8500000000000001, XGBRegressor__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -8.557179053624472},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.2, RandomForestRegressor__min_samples_leaf=10, RandomForestRegressor__min_samples_split=19, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -6.9026852425568},
#  'AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -2.4694758389758387},
#  'LassoLarsCV(input_matrix, LassoLarsCV__normalize=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -1.5407821599448349e-06},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.9500000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=11, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -3.151659223543702},
#  'RandomForestRegressor(XGBRegressor(input_matrix, XGBRegressor__learning_rate=1.0, XGBRegressor__max_depth=10, XGBRegressor__min_child_weight=8, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.5, XGBRegressor__verbosity=0), RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.1, RandomForestRegressor__min_samples_leaf=15, RandomForestRegressor__min_samples_split=7, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -8.634310763707784},
#  'ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.45, ExtraTreesRegressor__min_samples_leaf=2, ExtraTreesRegressor__min_samples_split=9, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -8.310617623104188},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=55, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=uniform)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -inf},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=18, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -8.76814814814815},
#  'GradientBoostingRegressor(XGBRegressor(input_matrix, XGBRegressor__learning_rate=1.0, XGBRegressor__max_depth=2, XGBRegressor__min_child_weight=18, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.6500000000000001, XGBRegressor__verbosity=0), GradientBoostingRegressor__alpha=0.99, GradientBoostingRegressor__learning_rate=1.0, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.9000000000000001, GradientBoostingRegressor__min_samples_leaf=11, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.3)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -47.38666666666666},
#  'LinearSVR(input_matrix, LinearSVR__C=0.001, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -2.503319999999993},
#  'LassoLarsCV(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.01, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), LassoLarsCV__normalize=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -2.7544759101753395e-08},
#  'RidgeCV(input_matrix)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -8.977176734186483e-05},
#  'ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=1.0, ExtraTreesRegressor__min_samples_leaf=14, ExtraTreesRegressor__min_samples_split=12, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -14.26032119570774},
#  'XGBRegressor(input_matrix, XGBRegressor__learning_rate=1.0, XGBRegressor__max_depth=7, XGBRegressor__min_child_weight=14, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.7000000000000001, XGBRegressor__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -7.702944366137187},
#  'RidgeCV(ZeroCount(input_matrix))': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -9.234861070723059e-05},
#  'ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.30000000000000004, ElasticNetCV__tol=0.0001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.0484056806191802},
#  'AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.1, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -2.6914353809245446},
#  'XGBRegressor(input_matrix, XGBRegressor__learning_rate=0.001, XGBRegressor__max_depth=4, XGBRegressor__min_child_weight=6, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.6500000000000001, XGBRegressor__verbosity=0)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -17.811979182561238},
#  'LinearSVR(RidgeCV(input_matrix), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -0.008477616003115786},
#  'GradientBoostingRegressor(KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=25, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance), GradientBoostingRegressor__alpha=0.99, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=7, GradientBoostingRegressor__max_features=0.6000000000000001, GradientBoostingRegressor__min_samples_leaf=3, GradientBoostingRegressor__min_samples_split=14, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.55)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -7.077397290242328},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6500000000000001, RandomForestRegressor__min_samples_leaf=12, RandomForestRegressor__min_samples_split=15, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -7.620855467286398},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=6, GradientBoostingRegressor__max_features=0.9000000000000001, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=13, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.6000000000000001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -8.214000492504715},
#  'LinearSVR(input_matrix, LinearSVR__C=10.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -0.0007617789086765346},
#  'AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=linear, AdaBoostRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -2.707466844158021},
#  'DecisionTreeRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=5, DecisionTreeRegressor__min_samples_leaf=5, DecisionTreeRegressor__min_samples_split=3), DecisionTreeRegressor__max_depth=7, DecisionTreeRegressor__min_samples_leaf=15, DecisionTreeRegressor__min_samples_split=16)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -8.729011260826168},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.8500000000000001, GradientBoostingRegressor__min_samples_leaf=4, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.15000000000000002)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -15.255080654661542},
#  'RandomForestRegressor(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=1.0, ExtraTreesRegressor__min_samples_leaf=8, ExtraTreesRegressor__min_samples_split=2, ExtraTreesRegressor__n_estimators=100), RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.05, RandomForestRegressor__min_samples_leaf=14, RandomForestRegressor__min_samples_split=14, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -7.735355975723622},
#  'ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.15000000000000002, ExtraTreesRegressor__min_samples_leaf=2, ExtraTreesRegressor__min_samples_split=15, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -7.970452524736318},
#  'LassoLarsCV(Binarizer(input_matrix, Binarizer__threshold=0.05), LassoLarsCV__normalize=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -inf},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -3.1367339241646444},
#  'LassoLarsCV(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -1.5407821599448349e-06},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6000000000000001, RandomForestRegressor__min_samples_leaf=4, RandomForestRegressor__min_samples_split=7, RandomForestRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -3.37691759767208},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=19, DecisionTreeRegressor__min_samples_split=15)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -8.773454790823212},
#  'DecisionTreeRegressor(LassoLarsCV(input_matrix, LassoLarsCV__normalize=False), DecisionTreeRegressor__max_depth=5, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=7)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -8.68922969187675},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=1.0, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -3.5460288427794544},
#  'GradientBoostingRegressor(RobustScaler(input_matrix), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=8, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.3)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -7.4979175987197335},
#  'ExtraTreesRegressor(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.9000000000000001, ExtraTreesRegressor__min_samples_leaf=13, ExtraTreesRegressor__min_samples_split=16, ExtraTreesRegressor__n_estimators=100), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.05, ExtraTreesRegressor__min_samples_leaf=18, ExtraTreesRegressor__min_samples_split=3, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -14.52672740740741},
#  'AdaBoostRegressor(DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=7, DecisionTreeRegressor__min_samples_leaf=19, DecisionTreeRegressor__min_samples_split=15), AdaBoostRegressor__learning_rate=0.01, AdaBoostRegressor__loss=exponential, AdaBoostRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -2.961446185508105},
#  'RidgeCV(CombineDFs(input_matrix, input_matrix))': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -4.488649176858021e-05},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.99, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=5, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=15, GradientBoostingRegressor__min_samples_split=12, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -7.129191081692621},
#  'ElasticNetCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.7000000000000001, ElasticNetCV__tol=0.001), ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.0001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -0.015261696589489778},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.1, GradientBoostingRegressor__loss=ls, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.4, GradientBoostingRegressor__min_samples_leaf=10, GradientBoostingRegressor__min_samples_split=8, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9000000000000001)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -4.700269764892272},
#  'LassoLarsCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.0001), LassoLarsCV__normalize=False)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -3.3825311949353676e-06},
#  'GradientBoostingRegressor(LinearSVR(input_matrix, LinearSVR__C=10.0, LinearSVR__dual=False, LinearSVR__epsilon=0.01, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=1e-05), GradientBoostingRegressor__alpha=0.99, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=6, GradientBoostingRegressor__max_features=0.4, GradientBoostingRegressor__min_samples_leaf=4, GradientBoostingRegressor__min_samples_split=3, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.3)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -14.640435793596541},
#  'SGDRegressor(input_matrix, SGDRegressor__alpha=0.001, SGDRegressor__eta0=0.01, SGDRegressor__fit_intercept=True, SGDRegressor__l1_ratio=0.25, SGDRegressor__learning_rate=constant, SGDRegressor__loss=squared_loss, SGDRegressor__penalty=elasticnet, SGDRegressor__power_t=0.1)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 1,
#   'internal_cv_score': -2388056268798.027},
#  'ExtraTreesRegressor(Nystroem(input_matrix, Nystroem__gamma=0.75, Nystroem__kernel=rbf, Nystroem__n_components=10), ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.7000000000000001, ExtraTreesRegressor__min_samples_leaf=3, ExtraTreesRegressor__min_samples_split=15, ExtraTreesRegressor__n_estimators=100)': {'generation': 0,
#   'mutation_count': 0,
#   'crossover_count': 0,
#   'predecessor': ('ROOT',),
#   'operator_count': 2,
#   'internal_cv_score': -10.507257098541368},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6000000000000001, RandomForestRegressor__min_samples_leaf=18, RandomForestRegressor__min_samples_split=7, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6000000000000001, RandomForestRegressor__min_samples_leaf=4, RandomForestRegressor__min_samples_split=7, RandomForestRegressor__n_estimators=100)',
#    'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=18, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)'),
#   'operator_count': 1,
#   'internal_cv_score': -14.52672740740741},
#  'AdaBoostRegressor(Binarizer(input_matrix, Binarizer__threshold=0.4), AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -14.200906350324953},
#  'RidgeCV(CombineDFs(input_matrix, StandardScaler(input_matrix)))': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(CombineDFs(input_matrix, input_matrix))',),
#   'operator_count': 2,
#   'internal_cv_score': -8.948649123529267e-05},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.9500000000000001, RandomForestRegressor__min_samples_leaf=12, RandomForestRegressor__min_samples_split=15, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6500000000000001, RandomForestRegressor__min_samples_leaf=12, RandomForestRegressor__min_samples_split=15, RandomForestRegressor__n_estimators=100)',
#    'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.9500000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=11, RandomForestRegressor__n_estimators=100)'),
#   'operator_count': 1,
#   'internal_cv_score': -7.620855467286398},
#  'AdaBoostRegressor(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.001, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -2.5523543031043037},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=5, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=15, GradientBoostingRegressor__min_samples_split=12, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.99, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=5, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=15, GradientBoostingRegressor__min_samples_split=12, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)',),
#   'operator_count': 1,
#   'internal_cv_score': -6.982537574741626},
#  'AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.1, AdaBoostRegressor__loss=linear, AdaBoostRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.1, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)',
#    'AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=linear, AdaBoostRegressor__n_estimators=100)'),
#   'operator_count': 1,
#   'internal_cv_score': -2.883725506891915},
#  'GradientBoostingRegressor(ZeroCount(input_matrix), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.8500000000000001, GradientBoostingRegressor__min_samples_leaf=4, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.15000000000000002)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=0.8500000000000001, GradientBoostingRegressor__min_samples_leaf=4, GradientBoostingRegressor__min_samples_split=16, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.15000000000000002)',),
#   'operator_count': 2,
#   'internal_cv_score': -15.255080654661542},
#  'ElasticNetCV(ElasticNetCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.7000000000000001, ElasticNetCV__tol=0.001), ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.0001), ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.0001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.7000000000000001, ElasticNetCV__tol=0.001), ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.0001)',),
#   'operator_count': 3,
#   'internal_cv_score': -0.014695861019815008},
#  'KNeighborsRegressor(input_matrix, KNeighborsRegressor__n_neighbors=9, KNeighborsRegressor__p=1, KNeighborsRegressor__weights=distance)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': -2.676528344818378},
#  'DecisionTreeRegressor(MinMaxScaler(LassoLarsCV(input_matrix, LassoLarsCV__normalize=False)), DecisionTreeRegressor__max_depth=5, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=7)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(LassoLarsCV(input_matrix, LassoLarsCV__normalize=False), DecisionTreeRegressor__max_depth=5, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=7)',),
#   'operator_count': 3,
#   'internal_cv_score': -8.68922969187675},
#  'ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.7000000000000001, ExtraTreesRegressor__min_samples_leaf=13, ExtraTreesRegressor__min_samples_split=4, ExtraTreesRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': -12.41515723536278},
#  'LinearSVR(input_matrix, LinearSVR__C=0.001, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=0.001, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -2.503319999999993},
#  'LinearSVR(RidgeCV(input_matrix), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.1, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(RidgeCV(input_matrix), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.046938941150667296},
#  'LinearSVR(input_matrix, LinearSVR__C=5.0, LinearSVR__dual=False, LinearSVR__epsilon=0.01, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.016846187524429023},
#  'LinearSVR(RobustScaler(RidgeCV(input_matrix)), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(RidgeCV(input_matrix), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)',),
#   'operator_count': 3,
#   'internal_cv_score': -0.015409885771903924},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=1.0, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=1.0, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)',),
#   'operator_count': 1,
#   'internal_cv_score': -3.432127478436595},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=13, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -7.812106290068458},
#  'XGBRegressor(RBFSampler(input_matrix, RBFSampler__gamma=0.4), XGBRegressor__learning_rate=0.01, XGBRegressor__max_depth=6, XGBRegressor__min_child_weight=6, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.05, XGBRegressor__verbosity=0)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('XGBRegressor(RBFSampler(input_matrix, RBFSampler__gamma=0.4), XGBRegressor__learning_rate=0.01, XGBRegressor__max_depth=6, XGBRegressor__min_child_weight=16, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.05, XGBRegressor__verbosity=0)',
#    'XGBRegressor(input_matrix, XGBRegressor__learning_rate=0.001, XGBRegressor__max_depth=4, XGBRegressor__min_child_weight=6, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.6500000000000001, XGBRegressor__verbosity=0)'),
#   'operator_count': 2,
#   'internal_cv_score': -18.002942975362142},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.85, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=9, GradientBoostingRegressor__max_features=0.8, GradientBoostingRegressor__min_samples_leaf=5, GradientBoostingRegressor__min_samples_split=12, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.45, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=9, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -2.888141296001288},
#  'GradientBoostingRegressor(RobustScaler(input_matrix), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=8, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=5, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.3)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(RobustScaler(input_matrix), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=8, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.3)',),
#   'operator_count': 2,
#   'internal_cv_score': -6.3620760592111365},
#  'LinearSVR(RobustScaler(input_matrix), LinearSVR__C=10.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=10.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.017796487317556623},
#  'LinearSVR(Nystroem(input_matrix, Nystroem__gamma=0.1, Nystroem__kernel=additive_chi2, Nystroem__n_components=9), LinearSVR__C=10.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=10.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.2473898451160097},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.99, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=5, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=15, GradientBoostingRegressor__min_samples_split=12, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)': {'generation': 1,
#   'mutation_count': 0,
#   'crossover_count': 1,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.99, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=5, GradientBoostingRegressor__max_features=0.7500000000000001, GradientBoostingRegressor__min_samples_leaf=15, GradientBoostingRegressor__min_samples_split=12, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.9500000000000001)',
#    'GradientBoostingRegressor(RobustScaler(input_matrix), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=8, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.3)'),
#   'operator_count': 1,
#   'internal_cv_score': -32.355764400048685},
#  'SGDRegressor(StandardScaler(input_matrix), SGDRegressor__alpha=0.001, SGDRegressor__eta0=0.01, SGDRegressor__fit_intercept=True, SGDRegressor__l1_ratio=0.25, SGDRegressor__learning_rate=constant, SGDRegressor__loss=squared_loss, SGDRegressor__penalty=elasticnet, SGDRegressor__power_t=0.1)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('SGDRegressor(input_matrix, SGDRegressor__alpha=0.001, SGDRegressor__eta0=0.01, SGDRegressor__fit_intercept=True, SGDRegressor__l1_ratio=0.25, SGDRegressor__learning_rate=constant, SGDRegressor__loss=squared_loss, SGDRegressor__penalty=elasticnet, SGDRegressor__power_t=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.010847371436052739},
#  'RidgeCV(Nystroem(input_matrix, Nystroem__gamma=0.0, Nystroem__kernel=additive_chi2, Nystroem__n_components=1))': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 2,
#   'internal_cv_score': -829.0371808357273},
#  'XGBRegressor(RBFSampler(input_matrix, RBFSampler__gamma=1.0), XGBRegressor__learning_rate=0.01, XGBRegressor__max_depth=6, XGBRegressor__min_child_weight=16, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.05, XGBRegressor__verbosity=0)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('XGBRegressor(RBFSampler(input_matrix, RBFSampler__gamma=0.4), XGBRegressor__learning_rate=0.01, XGBRegressor__max_depth=6, XGBRegressor__min_child_weight=16, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.05, XGBRegressor__verbosity=0)',),
#   'operator_count': 2,
#   'internal_cv_score': -19.4199999332428},
#  'GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=8, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.3)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(RobustScaler(input_matrix), GradientBoostingRegressor__alpha=0.8, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=quantile, GradientBoostingRegressor__max_depth=8, GradientBoostingRegressor__max_features=0.6500000000000001, GradientBoostingRegressor__min_samples_leaf=2, GradientBoostingRegressor__min_samples_split=4, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.3)',),
#   'operator_count': 1,
#   'internal_cv_score': -7.414455457236784},
#  'LassoLarsCV(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=False)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)',),
#   'operator_count': 2,
#   'internal_cv_score': -1.5387888356599435e-06},
#  'RandomForestRegressor(GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.01, GradientBoostingRegressor__loss=lad, GradientBoostingRegressor__max_depth=7, GradientBoostingRegressor__max_features=0.8500000000000001, GradientBoostingRegressor__min_samples_leaf=12, GradientBoostingRegressor__min_samples_split=20, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6500000000000001, RandomForestRegressor__min_samples_leaf=12, RandomForestRegressor__min_samples_split=15, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.6500000000000001, RandomForestRegressor__min_samples_leaf=12, RandomForestRegressor__min_samples_split=15, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -7.695309122348289},
#  'ExtraTreesRegressor(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0005), ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.4, ExtraTreesRegressor__min_samples_leaf=10, ExtraTreesRegressor__min_samples_split=13, ExtraTreesRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)',),
#   'operator_count': 2,
#   'internal_cv_score': -12.250596991981256},
#  'AdaBoostRegressor(SGDRegressor(input_matrix, SGDRegressor__alpha=0.01, SGDRegressor__eta0=0.1, SGDRegressor__fit_intercept=False, SGDRegressor__l1_ratio=1.0, SGDRegressor__learning_rate=invscaling, SGDRegressor__loss=epsilon_insensitive, SGDRegressor__penalty=elasticnet, SGDRegressor__power_t=0.1), AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)',),
#   'operator_count': 2,
#   'internal_cv_score': -2.4355096136171652},
#  'LassoLarsCV(input_matrix, LassoLarsCV__normalize=False)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.01, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), LassoLarsCV__normalize=False)',),
#   'operator_count': 1,
#   'internal_cv_score': -1.5387888356599435e-06},
#  'DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=17, DecisionTreeRegressor__min_samples_split=15)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('DecisionTreeRegressor(input_matrix, DecisionTreeRegressor__max_depth=6, DecisionTreeRegressor__min_samples_leaf=19, DecisionTreeRegressor__min_samples_split=15)',),
#   'operator_count': 1,
#   'internal_cv_score': -8.68922969187675},
#  'GradientBoostingRegressor(LinearSVR(input_matrix, LinearSVR__C=0.0001, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.01), GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=1.0, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('GradientBoostingRegressor(input_matrix, GradientBoostingRegressor__alpha=0.75, GradientBoostingRegressor__learning_rate=0.5, GradientBoostingRegressor__loss=huber, GradientBoostingRegressor__max_depth=1, GradientBoostingRegressor__max_features=1.0, GradientBoostingRegressor__min_samples_leaf=6, GradientBoostingRegressor__min_samples_split=18, GradientBoostingRegressor__n_estimators=100, GradientBoostingRegressor__subsample=0.7500000000000001)',),
#   'operator_count': 2,
#   'internal_cv_score': -3.519577126400092},
#  'RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=18, RandomForestRegressor__min_samples_split=6, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RandomForestRegressor(input_matrix, RandomForestRegressor__bootstrap=False, RandomForestRegressor__max_features=0.4, RandomForestRegressor__min_samples_leaf=18, RandomForestRegressor__min_samples_split=16, RandomForestRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -8.76814814814815},
#  'LinearSVR(RidgeCV(Normalizer(input_matrix, Normalizer__norm=max)), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(RidgeCV(input_matrix), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)',),
#   'operator_count': 3,
#   'internal_cv_score': -14.575248541111627},
#  'LassoLarsCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.001), LassoLarsCV__normalize=False)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.0001), LassoLarsCV__normalize=False)',),
#   'operator_count': 2,
#   'internal_cv_score': -3.3825311949353676e-06},
#  'AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.5, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100)',),
#   'operator_count': 1,
#   'internal_cv_score': -2.426104041182989},
#  'RandomForestRegressor(CombineDFs(input_matrix, input_matrix), RandomForestRegressor__bootstrap=True, RandomForestRegressor__max_features=0.9500000000000001, RandomForestRegressor__min_samples_leaf=2, RandomForestRegressor__min_samples_split=11, RandomForestRegressor__n_estimators=100)': {'generation': 1,
#   'mutation_count': 1,
# ...
#   'operator_count': 3,
#   'internal_cv_score': -8.128463469670549e-05},
#  'LassoLarsCV(PCA(VarianceThreshold(RobustScaler(input_matrix), VarianceThreshold__threshold=0.0005), PCA__iterated_power=1, PCA__svd_solver=randomized), LassoLarsCV__normalize=True)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 1,
#   'predecessor': ('LassoLarsCV(VarianceThreshold(RobustScaler(input_matrix), VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)',),
#   'operator_count': 4,
#   'internal_cv_score': -1.8377849822689045e-06},
#  'LassoLarsCV(Normalizer(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0005), Normalizer__norm=l2), LassoLarsCV__normalize=True)': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)',),
#   'operator_count': 3,
#   'internal_cv_score': -inf},
#  'LinearSVR(input_matrix, LinearSVR__C=0.5, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=10.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.02061391930832693},
#  'RidgeCV(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.3, ExtraTreesRegressor__min_samples_leaf=16, ExtraTreesRegressor__min_samples_split=13, ExtraTreesRegressor__n_estimators=100))': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(SGDRegressor(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.3, ExtraTreesRegressor__min_samples_leaf=16, ExtraTreesRegressor__min_samples_split=13, ExtraTreesRegressor__n_estimators=100), SGDRegressor__alpha=0.01, SGDRegressor__eta0=0.01, SGDRegressor__fit_intercept=True, SGDRegressor__l1_ratio=0.0, SGDRegressor__learning_rate=constant, SGDRegressor__loss=huber, SGDRegressor__penalty=elasticnet, SGDRegressor__power_t=0.5))',),
#   'operator_count': 2,
#   'internal_cv_score': -8.841757322616787e-05},
#  'RidgeCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.25, ElasticNetCV__tol=1e-05))': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.8500000000000001, ElasticNetCV__tol=1e-05))',),
#   'operator_count': 2,
#   'internal_cv_score': -4.5030053730468894e-05},
#  'LinearSVR(ZeroCount(input_matrix), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.02419430929983166},
#  'LassoLarsCV(VarianceThreshold(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), VarianceThreshold__threshold=0.005), LassoLarsCV__normalize=False)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), LassoLarsCV__normalize=False)',),
#   'operator_count': 3,
#   'internal_cv_score': -2.148192593967987e-09},
#  'LassoLarsCV(SelectPercentile(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.001), SelectPercentile__percentile=69), LassoLarsCV__normalize=False)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=0.8, ElasticNetCV__tol=0.001), LassoLarsCV__normalize=False)',),
#   'operator_count': 3,
#   'internal_cv_score': -1.6349675280480369e-06},
#  'LassoLarsCV(MaxAbsScaler(input_matrix), LassoLarsCV__normalize=False)': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 1,
#   'predecessor': ('LassoLarsCV(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.01, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), LassoLarsCV__normalize=False)',
#    'LassoLarsCV(OneHotEncoder(ExtraTreesRegressor(MaxAbsScaler(input_matrix), ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.6500000000000001, ExtraTreesRegressor__min_samples_leaf=6, ExtraTreesRegressor__min_samples_split=2, ExtraTreesRegressor__n_estimators=100), OneHotEncoder__minimum_fraction=0.1, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10), LassoLarsCV__normalize=False)'),
#   'operator_count': 2,
#   'internal_cv_score': -1.795620455785259e-06},
#  'XGBRegressor(input_matrix, XGBRegressor__learning_rate=0.1, XGBRegressor__max_depth=9, XGBRegressor__min_child_weight=7, XGBRegressor__n_estimators=100, XGBRegressor__n_jobs=1, XGBRegressor__objective=reg:squarederror, XGBRegressor__subsample=0.5, XGBRegressor__verbosity=0)': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(input_matrix)',),
#   'operator_count': 1,
#   'internal_cv_score': -4.77430185675621},
#  'LinearSVR(input_matrix, LinearSVR__C=15.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 5,
#   'mutation_count': 4,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=15.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.0001584222460273491},
#  'DecisionTreeRegressor(CombineDFs(input_matrix, StandardScaler(input_matrix)), DecisionTreeRegressor__max_depth=8, DecisionTreeRegressor__min_samples_leaf=13, DecisionTreeRegressor__min_samples_split=10)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(CombineDFs(input_matrix, StandardScaler(input_matrix)))',),
#   'operator_count': 2,
#   'internal_cv_score': -6.994256008611272},
#  'LassoLarsCV(VarianceThreshold(PolynomialFeatures(StandardScaler(input_matrix), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(VarianceThreshold(StandardScaler(input_matrix), VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)',),
#   'operator_count': 4,
#   'internal_cv_score': -4.585121661773902e-06},
#  'LinearSVR(CombineDFs(input_matrix, input_matrix), LinearSVR__C=25.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 1,
#   'predecessor': ('LinearSVR(CombineDFs(input_matrix, input_matrix), LinearSVR__C=25.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.01)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.0021048897244634076},
#  'LinearSVR(input_matrix, LinearSVR__C=0.5, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=10.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.001)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.0001584222460273491},
#  'LassoLarsCV(VarianceThreshold(VarianceThreshold(StandardScaler(input_matrix), VarianceThreshold__threshold=0.0005), VarianceThreshold__threshold=0.0001), LassoLarsCV__normalize=True)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(VarianceThreshold(StandardScaler(input_matrix), VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)',),
#   'operator_count': 4,
#   'internal_cv_score': -1.5945263629172739e-06},
#  'LassoLarsCV(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.001, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), LassoLarsCV__normalize=False)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), LassoLarsCV__normalize=False)',),
#   'operator_count': 2,
#   'internal_cv_score': -2.7110089935907427e-08},
#  'LassoLarsCV(StandardScaler(StandardScaler(input_matrix)), LassoLarsCV__normalize=True)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(StandardScaler(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.0005)), LassoLarsCV__normalize=True)',),
#   'operator_count': 3,
#   'internal_cv_score': -1.6044238961991179e-06},
#  'LassoLarsCV(RBFSampler(input_matrix, RBFSampler__gamma=0.8), LassoLarsCV__normalize=True)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.01, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), LassoLarsCV__normalize=True)',),
#   'operator_count': 2,
#   'internal_cv_score': -3.0143338120704555},
#  'LinearSVR(ExtraTreesRegressor(SelectFromModel(input_matrix, SelectFromModel__ExtraTreesRegressor__max_features=0.35000000000000003, SelectFromModel__ExtraTreesRegressor__n_estimators=100, SelectFromModel__threshold=0.25), ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.35000000000000003, ExtraTreesRegressor__min_samples_leaf=19, ExtraTreesRegressor__min_samples_split=3, ExtraTreesRegressor__n_estimators=100), LinearSVR__C=10.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=False, ExtraTreesRegressor__max_features=0.35000000000000003, ExtraTreesRegressor__min_samples_leaf=19, ExtraTreesRegressor__min_samples_split=3, ExtraTreesRegressor__n_estimators=100), LinearSVR__C=10.0, LinearSVR__dual=False, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)',),
#   'operator_count': 3,
#   'internal_cv_score': -0.00012269146048050238},
#  'LinearSVR(input_matrix, LinearSVR__C=15.0, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)': {'generation': 5,
#   'mutation_count': 2,
#   'crossover_count': 0,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=epsilon_insensitive, LinearSVR__tol=0.1)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.010261360449571355},
#  'LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.01, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 5,
#   'mutation_count': 5,
#   'crossover_count': 1,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)',),
#   'operator_count': 1,
#   'internal_cv_score': -0.008105500358245858},
#  'ElasticNetCV(PCA(input_matrix, PCA__iterated_power=6, PCA__svd_solver=randomized), ElasticNetCV__l1_ratio=1.0, ElasticNetCV__tol=0.0001)': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('ElasticNetCV(input_matrix, ElasticNetCV__l1_ratio=1.0, ElasticNetCV__tol=0.0001)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.014556433260440826},
#  'LassoLarsCV(PolynomialFeatures(AdaBoostRegressor(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.15, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10), AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), LassoLarsCV__normalize=False)': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('LassoLarsCV(PolynomialFeatures(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=1.0, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), LassoLarsCV__normalize=False)',),
#   'operator_count': 4,
#   'internal_cv_score': -5.2106098826490044e-08},
#  'RidgeCV(SGDRegressor(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.3, ExtraTreesRegressor__min_samples_leaf=16, ExtraTreesRegressor__min_samples_split=20, ExtraTreesRegressor__n_estimators=100), SGDRegressor__alpha=0.01, SGDRegressor__eta0=0.01, SGDRegressor__fit_intercept=True, SGDRegressor__l1_ratio=0.0, SGDRegressor__learning_rate=constant, SGDRegressor__loss=huber, SGDRegressor__penalty=elasticnet, SGDRegressor__power_t=0.5))': {'generation': 5,
#   'mutation_count': 3,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(SGDRegressor(ExtraTreesRegressor(input_matrix, ExtraTreesRegressor__bootstrap=True, ExtraTreesRegressor__max_features=0.3, ExtraTreesRegressor__min_samples_leaf=16, ExtraTreesRegressor__min_samples_split=13, ExtraTreesRegressor__n_estimators=100), SGDRegressor__alpha=0.01, SGDRegressor__eta0=0.01, SGDRegressor__fit_intercept=True, SGDRegressor__l1_ratio=0.0, SGDRegressor__learning_rate=constant, SGDRegressor__loss=huber, SGDRegressor__penalty=elasticnet, SGDRegressor__power_t=0.5))',),
#   'operator_count': 3,
#   'internal_cv_score': -8.128463469670549e-05},
#  'RidgeCV(CombineDFs(input_matrix, ZeroCount(input_matrix)))': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 0,
#   'predecessor': ('RidgeCV(CombineDFs(input_matrix, input_matrix))',),
#   'operator_count': 2,
#   'internal_cv_score': -4.6174807816073605e-05},
#  'LinearSVR(LassoLarsCV(input_matrix, LassoLarsCV__normalize=True), LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)': {'generation': 5,
#   'mutation_count': 5,
#   'crossover_count': 1,
#   'predecessor': ('LinearSVR(input_matrix, LinearSVR__C=1.0, LinearSVR__dual=True, LinearSVR__epsilon=0.0001, LinearSVR__loss=squared_epsilon_insensitive, LinearSVR__tol=0.001)',),
#   'operator_count': 2,
#   'internal_cv_score': -0.0019227507588670339},
#  'LassoLarsCV(VarianceThreshold(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.1, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)': {'generation': 5,
#   'mutation_count': 1,
#   'crossover_count': 1,
#   'predecessor': ('LassoLarsCV(VarianceThreshold(AdaBoostRegressor(input_matrix, AdaBoostRegressor__learning_rate=0.01, AdaBoostRegressor__loss=square, AdaBoostRegressor__n_estimators=100), VarianceThreshold__threshold=0.0005), LassoLarsCV__normalize=True)',),
#   'operator_count': 3,
#   'internal_cv_score': -3.9293605406480004e-13}}

# %%
model.fitted_pipeline_
# Out:
# Pipeline(steps=[('stackingestimator',
#                  StackingEstimator(estimator=SGDRegressor(alpha=0.0, eta0=1.0,
#                                                           fit_intercept=False,
#                                                           l1_ratio=0.5,
#                                                           learning_rate='constant',
#                                                           loss='epsilon_insensitive',
#                                                           penalty='elasticnet',
#                                                           power_t=1.0,
#                                                           random_state=1))),
#                 ('variancethreshold', VarianceThreshold(threshold=0.0005)),
#                 ('lassolarscv', LassoLarsCV())])
